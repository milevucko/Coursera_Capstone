# %% [markdown]
# ## ||||||||| START of first part |||||||||

# %%
import pandas as pd

# %%
df_list = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M',attrs={"class": "sortable"})
df_list
# Out:
# [    Postal Code           Borough  \
#  0           M1A      Not assigned
#  1           M2A      Not assigned
#  2           M3A        North York
#  3           M4A        North York
#  4           M5A  Downtown Toronto
#  ..          ...               ...
#  175         M5Z      Not assigned
#  176         M6Z      Not assigned
#  177         M7Z      Not assigned
#  178         M8Z         Etobicoke
#  179         M9Z      Not assigned
#
#                                           Neighbourhood
#  0                                         Not assigned
#  1                                         Not assigned
#  2                                            Parkwoods
#  3                                     Victoria Village
#  4                            Regent Park, Harbourfront
#  ..                                                 ...
#  175                                       Not assigned
#  176                                       Not assigned
#  177                                       Not assigned
#  178  Mimico NW, The Queensway West, South of Bloor,...
#  179                                       Not assigned
#
#  [180 rows x 3 columns]]

# %%
type(df_list)
# Out:
# list

# %%
len(df_list)
# Out:
# 1

# %%
df_list[0]
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                          Neighbourhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 175                                       Not assigned
# 176                                       Not assigned
# 177                                       Not assigned
# 178  Mimico NW, The Queensway West, South of Bloor,...
# 179                                       Not assigned
#
# [180 rows x 3 columns]

# %%
type(df_list[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df = df_list[0]
df
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                          Neighbourhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 175                                       Not assigned
# 176                                       Not assigned
# 177                                       Not assigned
# 178  Mimico NW, The Queensway West, South of Bloor,...
# 179                                       Not assigned
#
# [180 rows x 3 columns]

# %% [markdown]
# #### Ignore cells with a borough that is Not assigned.

# %%
df = df[df.Borough != 'Not assigned'] 
df = df.reset_index(drop=True)
df
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                          Neighbourhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Regent Park, Harbourfront
# 3                     Lawrence Manor, Lawrence Heights
# 4          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# 100  Business reply mail Processing Centre, South C...
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 102  Mimico NW, The Queensway West, South of Bloor,...
#
# [103 rows x 3 columns]

# %%
df[df['Postal Code'] == 'M5A']
# Out:
#   Postal Code           Borough              Neighbourhood
# 2         M5A  Downtown Toronto  Regent Park, Harbourfront

# %% [markdown]
# #### Check if a cell has a borough but a Not assigned  neighborhood

# %%
df[df['Neighbourhood'] == 'Not assigned']
# Out:
# Empty DataFrame
# Columns: [Postal Code, Borough, Neighbourhood]
# Index: []

# %% [markdown]
# No

# %%
df.shape
# Out:
# (103, 3)

# %%
print ('Dataframe df has {} rows, and {} columns'.format (df.shape[0], df.shape[1]))
# Out:
# Dataframe df has 103 rows, and 3 columns

# %% [markdown]
# ## ||||||||| END of first part |||||||||

# %% [markdown]
# ## ||||||||| START of second part |||||||||

# %%
# !pip install geocoder
# Out:
# Requirement already satisfied: geocoder in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (1.38.1)
# Requirement already satisfied: click in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geocoder) (7.1.2)
# Requirement already satisfied: ratelim in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: six in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geocoder) (1.15.0)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geocoder) (2.24.0)
# Requirement already satisfied: future in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geocoder) (0.18.2)
# Requirement already satisfied: decorator in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from ratelim->geocoder) (4.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->geocoder) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->geocoder) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->geocoder) (1.25.9)

# %%
import geocoder

# %%
def get_lat_long_from_postal_code(row):
    # initialize your variable to None
    lat_lng_coords = None

    # loop until you get the coordinates
    str_q='{}, Toronto, Ontario'.format(row['Postal Code'])
    print (str_q)

    while(lat_lng_coords is None):
        gc = geocoder.google(str_q)
        lat_lng_coords = gc.latlng

    latitude = lat_lng_coords[0]
    longitude = lat_lng_coords[1]
    
    print ("found one: " , latitude, longitude)
    return [latitude, longitude]

# %%
df['latitude_longitude'] = df.apply(get_lat_long_from_postal_code, axis=1)
# Out:
# M3A, Toronto, Ontario
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-b65fe953c058> in <module>
# ----> 1 df['latitude_longitude'] = df.apply(get_lat_long_from_postal_code, axis=1)
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     294             try:
#     295                 result = libreduction.compute_reduction(
# --> 296                     values, self.f, axis=self.axis, dummy=dummy, labels=labels
#     297                 )
#     298             except ValueError as err:
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.compute_reduction()
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.Reducer.get_result()
#
# <ipython-input-33-cfccc3a5280b> in get_lat_long_from_postal_code(row)
#       8
#       9     while(lat_lng_coords is None):
# ---> 10         gc = geocoder.google(str_q)
#      11         lat_lng_coords = gc.latlng
#      12
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/geocoder/api.py in google(location, **kwargs)
#     230         > elevation
#     231     """
# --> 232     return get(location, provider='google', **kwargs)
#     233
#     234
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/geocoder/api.py in get(location, **kwargs)
#     196         if method not in options[provider]:
#     197             raise ValueError("Invalid method")
# --> 198     return options[provider][method](location, **kwargs)
#     199
#     200
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/geocoder/base.py in __init__(self, location, **kwargs)
#     408
#     409         # query and parse results
# --> 410         self._initialize()
#     411
#     412     def __getitem__(self, key):
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/geocoder/base.py in _initialize(self)
#     455     def _initialize(self):
#     456         # query URL and get valid JSON (also stored in self.json)
# --> 457         json_response = self._connect()
#     458
#     459         # catch errors
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/geocoder/base.py in _connect(self)
#     482                 headers=self.headers,
#     483                 timeout=self.timeout,
# --> 484                 proxies=self.proxies
#     485             )
#     486
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/geocoder/google.py in rate_limited_get(self, *args, **kwargs)
#     267             return self.rate_limited_get_for_work(*args, **kwargs)
#     268         else:
# --> 269             return self.rate_limited_get_for_dev(*args, **kwargs)
#     270
#     271     @ratelim.greedy(2500, 60 * 60 * 24)
#
# <decorator-gen-128> in rate_limited_get_for_dev(self, *args, **kwargs)
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ratelim/__init__.py in wrapped_f(self, f, *args, **kwargs)
#      36
#      37         self.__numcalls += 1
# ---> 38         return f(*args, **kwargs)
#      39
#      40     def __call__(self, f, *args, **kwargs):
#
# <decorator-gen-127> in rate_limited_get_for_dev(self, *args, **kwargs)
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ratelim/__init__.py in wrapped_f(self, f, *args, **kwargs)
#      36
#      37         self.__numcalls += 1
# ---> 38         return f(*args, **kwargs)
#      39
#      40     def __call__(self, f, *args, **kwargs):
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/geocoder/google.py in rate_limited_get_for_dev(self, *args, **kwargs)
#     272     @ratelim.greedy(10, 1)
#     273     def rate_limited_get_for_dev(self, *args, **kwargs):
# --> 274         return super(GoogleQuery, self).rate_limited_get(*args, **kwargs)
#     275
#     276     @ratelim.greedy(100000, 60 * 60 * 24)  # Google for Work daily limit
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/geocoder/base.py in rate_limited_get(self, url, **kwargs)
#     508     def rate_limited_get(self, url, **kwargs):
#     509         """ By default, simply wraps a session.get request"""
# --> 510         return self.session.get(url, **kwargs)
#     511
#     512     def _adapt_results(self, json_response):
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     541
#     542         kwargs.setdefault('allow_redirects', True)
# --> 543         return self.request('GET', url, **kwargs)
#     544
#     545     def options(self, url, **kwargs):
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/http/client.py in getresponse(self)
#    1367         try:
#    1368             try:
# -> 1369                 response.begin()
#    1370             except ConnectionError:
#    1371                 self.close()
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/http/client.py in begin(self)
#     308         # read until we get a non-100 response
#     309         while True:
# --> 310             version, status, reason = self._read_status()
#     311             if status != CONTINUE:
#     312                 break
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/http/client.py in _read_status(self)
#     269
#     270     def _read_status(self):
# --> 271         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     272         if len(line) > _MAXLINE:
#     273             raise LineTooLong("status line")
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ### I had to interupt geocoder since it's not working properly (hangs). Let's try with geopy

# %%
# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
# Out:
# Requirement already satisfied: geopy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geopy) (1.50)

# %%
def get_lat_long_from_postal_code(row):
    # initialize your variable to None
    lat_lng_coords = None

    # loop until you get the coordinates
    str_q='{}, Toronto, Ontario'.format(row['Postal Code'])
    print (str_q)

    geolocator = Nominatim(user_agent="foursquare_agent")
    lat_lng_coords = geolocator.geocode(str_q)

    latitude = None
    longitude = None
    
    if lat_lng_coords:
        latitude = lat_lng_coords.latitude
        longitude = lat_lng_coords.longitude
    
    print ("found one: " , latitude, longitude)
    return [latitude, longitude]

# %%
df['latitude_longitude'] = df.apply(get_lat_long_from_postal_code, axis=1)
# Out:
# M3A, Toronto, Ontario
# found one:  43.6534817 -79.3839347
# M4A, Toronto, Ontario
# found one:  None None
# M5A, Toronto, Ontario
# found one:  None None
# M6A, Toronto, Ontario
# found one:  None None
# M7A, Toronto, Ontario
# found one:  43.6534817 -79.3839347
# M9A, Toronto, Ontario
# found one:  None None
# M1B, Toronto, Ontario
# found one:  43.6534817 -79.3839347
# M3B, Toronto, Ontario
# found one:  None None
# M4B, Toronto, Ontario
# found one:  None None
# M5B, Toronto, Ontario
# found one:  None None
# M6B, Toronto, Ontario
# found one:  None None
# M9B, Toronto, Ontario
# found one:  None None
# M1C, Toronto, Ontario
# found one:  43.6534817 -79.3839347
# M3C, Toronto, Ontario
# found one:  None None
# M4C, Toronto, Ontario
# found one:  None None
# M5C, Toronto, Ontario
# found one:  None None
# M6C, Toronto, Ontario
# found one:  None None
# M9C, Toronto, Ontario
# found one:  43.64410993066079 -79.58890692194828
# M1E, Toronto, Ontario
# found one:  None None
# M4E, Toronto, Ontario
# found one:  None None
# M5E, Toronto, Ontario
# found one:  43.6421064 -79.3774455
# M6E, Toronto, Ontario
# found one:  None None
# M1G, Toronto, Ontario
# found one:  43.76571676956549 -79.22189842824983
# M4G, Toronto, Ontario
# found one:  None None
# M5G, Toronto, Ontario
# found one:  None None
# M6G, Toronto, Ontario
# found one:  None None
# M1H, Toronto, Ontario
# found one:  None None
# M2H, Toronto, Ontario
# found one:  None None
# M3H, Toronto, Ontario
# found one:  None None
# M4H, Toronto, Ontario
# found one:  None None
# M5H, Toronto, Ontario
# found one:  43.649900711937015 -79.38371829639617
# M6H, Toronto, Ontario
# found one:  None None
# M1J, Toronto, Ontario
# found one:  None None
# M2J, Toronto, Ontario
# found one:  43.7797719 -79.3661846
# M3J, Toronto, Ontario
# found one:  None None
# M4J, Toronto, Ontario
# found one:  None None
# M5J, Toronto, Ontario
# found one:  43.63925859999999 -79.38283994999999
# M6J, Toronto, Ontario
# found one:  None None
# M1K, Toronto, Ontario
# found one:  None None
# M2K, Toronto, Ontario
# found one:  None None
# M3K, Toronto, Ontario
# found one:  None None
# M4K, Toronto, Ontario
# found one:  None None
# M5K, Toronto, Ontario
# found one:  None None
# M6K, Toronto, Ontario
# found one:  43.63709690913502 -79.4349584391061
# M1L, Toronto, Ontario
# found one:  None None
# M2L, Toronto, Ontario
# found one:  None None
# M3L, Toronto, Ontario
# found one:  None None
# M4L, Toronto, Ontario
# found one:  None None
# M5L, Toronto, Ontario
# found one:  None None
# M6L, Toronto, Ontario
# found one:  None None
# M9L, Toronto, Ontario
# found one:  None None
# M1M, Toronto, Ontario
# found one:  None None
# M2M, Toronto, Ontario
# found one:  43.7859621 -79.4160307769213
# M3M, Toronto, Ontario
# found one:  None None
# M4M, Toronto, Ontario
# found one:  None None
# M5M, Toronto, Ontario
# found one:  None None
# M6M, Toronto, Ontario
# found one:  None None
# M9M, Toronto, Ontario
# found one:  None None
# M1N, Toronto, Ontario
# found one:  None None
# M2N, Toronto, Ontario
# found one:  43.7792385670669 -79.41659335433374
# M3N, Toronto, Ontario
# found one:  None None
# M4N, Toronto, Ontario
# found one:  None None
# M5N, Toronto, Ontario
# found one:  None None
# M6N, Toronto, Ontario
# found one:  43.67455344769015 -79.48339767095568
# M9N, Toronto, Ontario
# found one:  None None
# M1P, Toronto, Ontario
# found one:  None None
# M2P, Toronto, Ontario
# found one:  None None
# M4P, Toronto, Ontario
# found one:  None None
# M5P, Toronto, Ontario
# found one:  None None
# M6P, Toronto, Ontario
# found one:  43.660631842593546 -79.4645105750826
# M9P, Toronto, Ontario
# found one:  None None
# M1R, Toronto, Ontario
# found one:  None None
# M2R, Toronto, Ontario
# found one:  None None
# M4R, Toronto, Ontario
# found one:  None None
# M5R, Toronto, Ontario
# found one:  None None
# M6R, Toronto, Ontario
# found one:  None None
# M7R, Toronto, Ontario
# found one:  None None
# M9R, Toronto, Ontario
# found one:  43.69516618990701 -79.55088985426742
# M1S, Toronto, Ontario
# found one:  None None
# M4S, Toronto, Ontario
# found one:  None None
# M5S, Toronto, Ontario
# found one:  None None
# M6S, Toronto, Ontario
# found one:  43.64986978220556 -79.47975776422314
# M1T, Toronto, Ontario
# found one:  None None
# M4T, Toronto, Ontario
# found one:  None None
# M5T, Toronto, Ontario
# found one:  None None
# M1V, Toronto, Ontario
# found one:  None None
# M4V, Toronto, Ontario
# found one:  None None
# M5V, Toronto, Ontario
# found one:  43.6456336 -79.39298744692186
# M8V, Toronto, Ontario
# found one:  None None
# M9V, Toronto, Ontario
# found one:  None None
# M1W, Toronto, Ontario
# found one:  43.81545466594209 -79.32772103687641
# M4W, Toronto, Ontario
# found one:  None None
# M5W, Toronto, Ontario
# found one:  None None
# M8W, Toronto, Ontario
# found one:  None None
# M9W, Toronto, Ontario
# found one:  None None
# M1X, Toronto, Ontario
# found one:  None None
# M4X, Toronto, Ontario
# found one:  43.6680266 -79.3692816
# M5X, Toronto, Ontario
# found one:  None None
# M8X, Toronto, Ontario
# found one:  None None
# M4Y, Toronto, Ontario
# found one:  None None
# M7Y, Toronto, Ontario
# found one:  None None
# M8Y, Toronto, Ontario
# found one:  None None
# M8Z, Toronto, Ontario
# found one:  None None

# %%
df
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                          Neighbourhood  \
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Regent Park, Harbourfront
# 3                     Lawrence Manor, Lawrence Heights
# 4          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# 100  Business reply mail Processing Centre, South C...
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 102  Mimico NW, The Queensway West, South of Bloor,...
#
#             latitude_longitude
# 0    [43.6534817, -79.3839347]
# 1                 [None, None]
# 2                 [None, None]
# 3                 [None, None]
# 4    [43.6534817, -79.3839347]
# ..                         ...
# 98                [None, None]
# 99                [None, None]
# 100               [None, None]
# 101               [None, None]
# 102               [None, None]
#
# [103 rows x 4 columns]

# %% [markdown]
# ### Since even this is not too good, I'm going to use Geospatial_Coordinates.csv and load that data in pandas dataframe

# %% [markdown]
# #### First, drop column 'latitude_longitude' since the data is not too good

# %%
df.drop(columns='latitude_longitude', axis=1, inplace=True)
df
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                          Neighbourhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Regent Park, Harbourfront
# 3                     Lawrence Manor, Lawrence Heights
# 4          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# 100  Business reply mail Processing Centre, South C...
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 102  Mimico NW, The Queensway West, South of Bloor,...
#
# [103 rows x 3 columns]

# %% [markdown]
# Load Geospatial_Coordinates.csv from url

# %%
gc = pd.read_csv('https://cocl.us/Geospatial_data')
gc
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# ..          ...        ...        ...
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %%
merged_df = df.merge(gc, how='inner', on="Postal Code")
merged_df
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Regent Park, Harbourfront  43.654260 -79.360636
# 3                     Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4          Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# ..                                                 ...        ...        ...
# 98       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 100  Business reply mail Processing Centre, South C...  43.662744 -79.321558
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...  43.636258 -79.498509
# 102  Mimico NW, The Queensway West, South of Bloor,...  43.628841 -79.520999
#
# [103 rows x 5 columns]

# %% [markdown]
# check first two rows

# %%
merged_df[merged_df["Postal Code"] == "M5G"]
# Out:
#    Postal Code           Borough       Neighbourhood   Latitude  Longitude
# 24         M5G  Downtown Toronto  Central Bay Street  43.657952 -79.387383

# %%
merged_df[merged_df["Postal Code"] == "M2H"]
# Out:
#    Postal Code     Borough      Neighbourhood   Latitude  Longitude
# 27         M2H  North York  Hillcrest Village  43.803762 -79.363452

# %% [markdown]
# ## ||||||||| END of second part |||||||||

# %% [markdown]
# ## ||||||||| START of third part |||||||||

# %%
pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.11.0-py2.py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 4.1 MB/s  eta 0:00:01
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.24.0)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.11.2)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (1.18.5)
# Collecting branca>=0.3.0
#   Downloading branca-0.4.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.2 folium-0.11.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

# %% [markdown]
# ### Work with only boroughs that contain the word Toronto

# %%
toronto_df = merged_df[merged_df.Borough.str.contains('toronto', case=False)]
toronto_df.reset_index(drop=True, inplace=True)
toronto_df
# Out:
#    Postal Code           Borough  \
# 0          M5A  Downtown Toronto
# 1          M7A  Downtown Toronto
# 2          M5B  Downtown Toronto
# 3          M5C  Downtown Toronto
# 4          M4E      East Toronto
# 5          M5E  Downtown Toronto
# 6          M5G  Downtown Toronto
# 7          M6G  Downtown Toronto
# 8          M5H  Downtown Toronto
# 9          M6H      West Toronto
# 10         M5J  Downtown Toronto
# 11         M6J      West Toronto
# 12         M4K      East Toronto
# 13         M5K  Downtown Toronto
# 14         M6K      West Toronto
# 15         M4L      East Toronto
# 16         M5L  Downtown Toronto
# 17         M4M      East Toronto
# 18         M4N   Central Toronto
# 19         M5N   Central Toronto
# 20         M4P   Central Toronto
# 21         M5P   Central Toronto
# 22         M6P      West Toronto
# 23         M4R   Central Toronto
# 24         M5R   Central Toronto
# 25         M6R      West Toronto
# 26         M4S   Central Toronto
# 27         M5S  Downtown Toronto
# 28         M6S      West Toronto
# 29         M4T   Central Toronto
# 30         M5T  Downtown Toronto
# 31         M4V   Central Toronto
# 32         M5V  Downtown Toronto
# 33         M4W  Downtown Toronto
# 34         M5W  Downtown Toronto
# 35         M4X  Downtown Toronto
# 36         M5X  Downtown Toronto
# 37         M4Y  Downtown Toronto
# 38         M7Y      East Toronto
#
#                                         Neighbourhood   Latitude  Longitude
# 0                           Regent Park, Harbourfront  43.654260 -79.360636
# 1         Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# 2                            Garden District, Ryerson  43.657162 -79.378937
# 3                                      St. James Town  43.651494 -79.375418
# 4                                         The Beaches  43.676357 -79.293031
# 5                                         Berczy Park  43.644771 -79.373306
# 6                                  Central Bay Street  43.657952 -79.387383
# 7                                            Christie  43.669542 -79.422564
# 8                            Richmond, Adelaide, King  43.650571 -79.384568
# 9                        Dufferin, Dovercourt Village  43.669005 -79.442259
# 10  Harbourfront East, Union Station, Toronto Islands  43.640816 -79.381752
# 11                           Little Portugal, Trinity  43.647927 -79.419750
# 12                       The Danforth West, Riverdale  43.679557 -79.352188
# 13           Toronto Dominion Centre, Design Exchange  43.647177 -79.381576
# 14       Brockton, Parkdale Village, Exhibition Place  43.636847 -79.428191
# 15                     India Bazaar, The Beaches West  43.668999 -79.315572
# 16                     Commerce Court, Victoria Hotel  43.648198 -79.379817
# 17                                    Studio District  43.659526 -79.340923
# 18                                      Lawrence Park  43.728020 -79.388790
# 19                                           Roselawn  43.711695 -79.416936
# 20                                   Davisville North  43.712751 -79.390197
# 21    Forest Hill North & West, Forest Hill Road Park  43.696948 -79.411307
# 22                      High Park, The Junction South  43.661608 -79.464763
# 23                  North Toronto West, Lawrence Park  43.715383 -79.405678
# 24                The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 25                             Parkdale, Roncesvalles  43.648960 -79.456325
# 26                                         Davisville  43.704324 -79.388790
# 27                     University of Toronto, Harbord  43.662696 -79.400049
# 28                                 Runnymede, Swansea  43.651571 -79.484450
# 29                        Moore Park, Summerhill East  43.689574 -79.383160
# 30          Kensington Market, Chinatown, Grange Park  43.653206 -79.400049
# 31  Summerhill West, Rathnelly, South Hill, Forest...  43.686412 -79.400049
# 32  CN Tower, King and Spadina, Railway Lands, Har...  43.628947 -79.394420
# 33                                           Rosedale  43.679563 -79.377529
# 34                                     Stn A PO Boxes  43.646435 -79.374846
# 35                        St. James Town, Cabbagetown  43.667967 -79.367675
# 36             First Canadian Place, Underground city  43.648429 -79.382280
# 37                               Church and Wellesley  43.665860 -79.383160
# 38  Business reply mail Processing Centre, South C...  43.662744 -79.321558

# %% [markdown]
# #### Create map of Toronto boroughs using latitude and longitude values

# %%
row = toronto_df[toronto_df.Borough == 'Downtown Toronto'].iloc[0, :]
latitude, longitude = row['Latitude'], row['Longitude']
latitude, longitude
# Out:
# (43.6542599, -79.3606359)

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(toronto_df['Latitude'], toronto_df['Longitude'], toronto_df['Borough'], toronto_df['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_d116914c8a404fcb86d13e7dedcac96a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_d116914c8a404fcb86d13e7dedcac96a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_d116914c8a404fcb86d13e7dedcac96a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_d116914c8a404fcb86d13e7dedcac96a%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6542599%2C%20-79.3606359%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
X = toronto_df.iloc[:,3:]
X
# Out:
#      Latitude  Longitude
# 0   43.654260 -79.360636
# 1   43.662301 -79.389494
# 2   43.657162 -79.378937
# 3   43.651494 -79.375418
# 4   43.676357 -79.293031
# 5   43.644771 -79.373306
# 6   43.657952 -79.387383
# 7   43.669542 -79.422564
# 8   43.650571 -79.384568
# 9   43.669005 -79.442259
# 10  43.640816 -79.381752
# 11  43.647927 -79.419750
# 12  43.679557 -79.352188
# 13  43.647177 -79.381576
# 14  43.636847 -79.428191
# 15  43.668999 -79.315572
# 16  43.648198 -79.379817
# 17  43.659526 -79.340923
# 18  43.728020 -79.388790
# 19  43.711695 -79.416936
# 20  43.712751 -79.390197
# 21  43.696948 -79.411307
# 22  43.661608 -79.464763
# 23  43.715383 -79.405678
# 24  43.672710 -79.405678
# 25  43.648960 -79.456325
# 26  43.704324 -79.388790
# 27  43.662696 -79.400049
# 28  43.651571 -79.484450
# 29  43.689574 -79.383160
# 30  43.653206 -79.400049
# 31  43.686412 -79.400049
# 32  43.628947 -79.394420
# 33  43.679563 -79.377529
# 34  43.646435 -79.374846
# 35  43.667967 -79.367675
# 36  43.648429 -79.382280
# 37  43.665860 -79.383160
# 38  43.662744 -79.321558

# %%
X = X.values[:,0:2]
X
# Out:
# array([[ 43.6542599, -79.3606359],
#        [ 43.6623015, -79.3894938],
#        [ 43.6571618, -79.3789371],
#        [ 43.6514939, -79.3754179],
#        [ 43.6763574, -79.2930312],
#        [ 43.6447708, -79.3733064],
#        [ 43.6579524, -79.3873826],
#        [ 43.669542 , -79.4225637],
#        [ 43.6505712, -79.3845675],
#        [ 43.6690051, -79.4422593],
#        [ 43.6408157, -79.3817523],
#        [ 43.6479267, -79.4197497],
#        [ 43.6795571, -79.352188 ],
#        [ 43.6471768, -79.3815764],
#        [ 43.6368472, -79.4281914],
#        [ 43.6689985, -79.3155716],
#        [ 43.6481985, -79.3798169],
#        [ 43.6595255, -79.340923 ],
#        [ 43.7280205, -79.3887901],
#        [ 43.7116948, -79.4169356],
#        [ 43.7127511, -79.3901975],
#        [ 43.6969476, -79.4113072],
#        [ 43.6616083, -79.4647633],
#        [ 43.7153834, -79.4056784],
#        [ 43.6727097, -79.4056784],
#        [ 43.6489597, -79.456325 ],
#        [ 43.7043244, -79.3887901],
#        [ 43.6626956, -79.4000493],
#        [ 43.6515706, -79.4844499],
#        [ 43.6895743, -79.3831599],
#        [ 43.6532057, -79.4000493],
#        [ 43.6864123, -79.4000493],
#        [ 43.6289467, -79.3944199],
#        [ 43.6795626, -79.3775294],
#        [ 43.6464352, -79.374846 ],
#        [ 43.667967 , -79.3676753],
#        [ 43.6484292, -79.3822802],
#        [ 43.6658599, -79.3831599],
#        [ 43.6627439, -79.321558 ]])

# %%
from sklearn.preprocessing import StandardScaler

cluster_dataset = StandardScaler().fit_transform(X)
cluster_dataset
# Out:
# array([[-0.55554658,  0.79089146],
#        [-0.20855993,  0.01026436],
#        [-0.43033262,  0.29583074],
#        [-0.67489659,  0.39102765],
#        [ 0.39793749,  2.61964756],
#        [-0.96499134,  0.44814526],
#        [-0.39621906,  0.06737385],
#        [ 0.10386009, -0.88430039],
#        [-0.71471013,  0.14352435],
#        [ 0.08069342, -1.41708063],
#        [-1.13564978,  0.21967755],
#        [-0.82881755, -0.80817965],
#        [ 0.53600121,  1.01941327],
#        [-0.86117495,  0.22443577],
#        [-1.30688641, -1.03653375],
#        [ 0.08040863,  2.00991342],
#        [-0.81708966,  0.27203152],
#        [-0.32834143,  1.32413968],
#        [ 2.62714635,  0.02929996],
#        [ 1.92270943, -0.7320562 ],
#        [ 1.96828767, -0.00877123],
#        [ 1.28638314, -0.57980391],
#        [-0.23847079, -2.02583013],
#        [ 2.08186867, -0.42754079],
#        [ 0.24054304, -0.42754079],
#        [-0.78424468, -1.79756801],
#        [ 1.60468436,  0.02929996],
#        [-0.19155492, -0.27526956],
#        [-0.67158707, -2.55836692],
#        [ 0.96823293,  0.18160095],
#        [-0.60103421, -0.27526956],
#        [ 0.83179593, -0.27526956],
#        [-1.64778475, -0.12299021],
#        [ 0.53623853,  0.33391005],
#        [-0.89317422,  0.40649796],
#        [ 0.03590049,  0.60047059],
#        [-0.8071352 ,  0.20539747],
#        [-0.05501868,  0.18160095],
#        [-0.18947083,  1.84797696]])

# %% [markdown]
# Create 3 clusters

# %%
num_clusters = 3

k_means = KMeans(init="k-means++", n_clusters=num_clusters, n_init=12)
k_means.fit(cluster_dataset)
labels = k_means.labels_

print(labels)
# Out:
# [1 1 1 1 1 1 1 2 1 2 1 2 1 1 2 1 1 1 0 0 0 0 2 0 1 2 0 1 2 0 1 0 1 1 1 1 1
#  1 1]

# %% [markdown]
# add labels to pandas dataframe

# %%
toronto_df.insert(0, 'cluster_label', labels)
toronto_df
# Out:
#     cluster_label Postal Code           Borough  \
# 0               1         M5A  Downtown Toronto
# 1               1         M7A  Downtown Toronto
# 2               1         M5B  Downtown Toronto
# 3               1         M5C  Downtown Toronto
# 4               1         M4E      East Toronto
# 5               1         M5E  Downtown Toronto
# 6               1         M5G  Downtown Toronto
# 7               2         M6G  Downtown Toronto
# 8               1         M5H  Downtown Toronto
# 9               2         M6H      West Toronto
# 10              1         M5J  Downtown Toronto
# 11              2         M6J      West Toronto
# 12              1         M4K      East Toronto
# 13              1         M5K  Downtown Toronto
# 14              2         M6K      West Toronto
# 15              1         M4L      East Toronto
# 16              1         M5L  Downtown Toronto
# 17              1         M4M      East Toronto
# 18              0         M4N   Central Toronto
# 19              0         M5N   Central Toronto
# 20              0         M4P   Central Toronto
# 21              0         M5P   Central Toronto
# 22              2         M6P      West Toronto
# 23              0         M4R   Central Toronto
# 24              1         M5R   Central Toronto
# 25              2         M6R      West Toronto
# 26              0         M4S   Central Toronto
# 27              1         M5S  Downtown Toronto
# 28              2         M6S      West Toronto
# 29              0         M4T   Central Toronto
# 30              1         M5T  Downtown Toronto
# 31              0         M4V   Central Toronto
# 32              1         M5V  Downtown Toronto
# 33              1         M4W  Downtown Toronto
# 34              1         M5W  Downtown Toronto
# 35              1         M4X  Downtown Toronto
# 36              1         M5X  Downtown Toronto
# 37              1         M4Y  Downtown Toronto
# 38              1         M7Y      East Toronto
#
#                                         Neighbourhood   Latitude  Longitude
# 0                           Regent Park, Harbourfront  43.654260 -79.360636
# 1         Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# 2                            Garden District, Ryerson  43.657162 -79.378937
# 3                                      St. James Town  43.651494 -79.375418
# 4                                         The Beaches  43.676357 -79.293031
# 5                                         Berczy Park  43.644771 -79.373306
# 6                                  Central Bay Street  43.657952 -79.387383
# 7                                            Christie  43.669542 -79.422564
# 8                            Richmond, Adelaide, King  43.650571 -79.384568
# 9                        Dufferin, Dovercourt Village  43.669005 -79.442259
# 10  Harbourfront East, Union Station, Toronto Islands  43.640816 -79.381752
# 11                           Little Portugal, Trinity  43.647927 -79.419750
# 12                       The Danforth West, Riverdale  43.679557 -79.352188
# 13           Toronto Dominion Centre, Design Exchange  43.647177 -79.381576
# 14       Brockton, Parkdale Village, Exhibition Place  43.636847 -79.428191
# 15                     India Bazaar, The Beaches West  43.668999 -79.315572
# 16                     Commerce Court, Victoria Hotel  43.648198 -79.379817
# 17                                    Studio District  43.659526 -79.340923
# 18                                      Lawrence Park  43.728020 -79.388790
# 19                                           Roselawn  43.711695 -79.416936
# 20                                   Davisville North  43.712751 -79.390197
# 21    Forest Hill North & West, Forest Hill Road Park  43.696948 -79.411307
# 22                      High Park, The Junction South  43.661608 -79.464763
# 23                  North Toronto West, Lawrence Park  43.715383 -79.405678
# 24                The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 25                             Parkdale, Roncesvalles  43.648960 -79.456325
# 26                                         Davisville  43.704324 -79.388790
# 27                     University of Toronto, Harbord  43.662696 -79.400049
# 28                                 Runnymede, Swansea  43.651571 -79.484450
# 29                        Moore Park, Summerhill East  43.689574 -79.383160
# 30          Kensington Market, Chinatown, Grange Park  43.653206 -79.400049
# 31  Summerhill West, Rathnelly, South Hill, Forest...  43.686412 -79.400049
# 32  CN Tower, King and Spadina, Railway Lands, Har...  43.628947 -79.394420
# 33                                           Rosedale  43.679563 -79.377529
# 34                                     Stn A PO Boxes  43.646435 -79.374846
# 35                        St. James Town, Cabbagetown  43.667967 -79.367675
# 36             First Canadian Place, Underground city  43.648429 -79.382280
# 37                               Church and Wellesley  43.665860 -79.383160
# 38  Business reply mail Processing Centre, South C...  43.662744 -79.321558

# %% [markdown]
# ## Let's visualize POIs with cluster labels on the folium map

# %%
import numpy as np

# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(num_clusters)
ys = [i + x + (i*x)**2 for i in range(num_clusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys) + 2))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_df['Latitude'], toronto_df['Longitude'], toronto_df['Neighbourhood'], toronto_df['cluster_label']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_a00d1dbd907b440eb4b5777b8af26429%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a00d1dbd907b440eb4b5777b8af26429%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_a00d1dbd907b440eb4b5777b8af26429%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_a00d1dbd907b440eb4b5777b8af26429%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6542599%2C%20-79.3606359%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ## ||||||||| END of third part |||||||||
